# %%
import torch
import torch.nn as nn
from utils.config import SimulationConfig, VAEConfig

# --- KVAE Skeleton ---
class KVAE(nn.Module):
    def __init__(self, cfg: VAEConfig):
        super().__init__()
        self.cfg = cfg

        # State transition matrices
        self.A_matrices = nn.ParameterList([nn.Parameter(torch.eye(cfg.dim_z)) for _ in range(cfg.num_matrices)])

        # Observation matrices
        self.C_matrices = nn.ParameterList([nn.Parameter(cfg.C_std * torch.randn(cfg.dim_a, cfg.dim_z)) for _ in range(cfg.num_matrices)])

        # Control matrices
        self.B_matrices = nn.ParameterList([nn.Parameter(cfg.B_std * torch.randn(cfg.dim_z, cfg.dim_z)) for _ in range(cfg.num_matrices)])

        # Noise covariances
        self.Q = cfg.Q_std * torch.eye(cfg.dim_z)    # Process noise covariance
        self.R = cfg.R_std * torch.eye(cfg.dim_a)    # Observation noise covariance

    def encode(self, x):
        """
        Encode observation to latent.
        """
        pass

    def decode(self, z):
        """
        Decode latent to observation (placeholder, to implement).
        """
        pass

    def forward(self, x):
        """
        Forward pass through KVAE:
        - encode x -> a
        - apply Kalman dynamics
        - decode a -> x_hat
        """
        pass

if __name__ == "__main__":
    cfg = VAEConfig()
    model = KVAE(cfg)

    # Dummy input: batch of 5 observations
    x_dummy = torch.randn(5, cfg.dim_a)
    x_pred = model(x_dummy)

    print("Input shape:", x_dummy.shape)
    print("Predicted shape:", x_pred.shape)
